# %% [markdown]
# # 12/17 課堂筆記（整理中）
#
# Status: draft
# Prereq: （課堂筆記/零散）
# Can-do checklist:
# - [ ] 能整理課堂筆記成可複習重點（待補）

# %%
def plus(x):
    p = 1
    x += p
    return x

# %%
a = 1

plus(a)
# Out:
# 101

# %%
a
# Out:
# 1

# %%
def multiply(x):
    mul = int(input("請輸入倍數"))
    return x * mul

multiply(4)
# Out:
# 20

# %%
a1 = 100
a1 = multiply(a1)
a1
# Out:
# 500
